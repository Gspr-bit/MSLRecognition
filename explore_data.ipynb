# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import sklearn.metrics as skmetrics
from scipy import stats
from math import sqrt

def tidy_corr_matrix(corr_mat) -> pd.DataFrame:
    """  
    Función para convertir una matriz de correlación de pandas en formato tidy.    """
    corr_mat = corr_mat.stack().reset_index()
    corr_mat.columns = ['A','B','Corr']
    corr_mat = corr_mat.loc[corr_mat['A'] != corr_mat['B'], :]
    corr_mat['|Corr|'] = np.abs(corr_mat['Corr'])
    corr_mat = corr_mat.sort_values('|Corr|', ascending=False, ignore_index=True)

    return corr_mat

def show_metrics(y_test, predictions):
    r2s = skmetrics.r2_score(y_test, predictions)
    mae = skmetrics.mean_absolute_error(y_test, predictions)
    mse = skmetrics.mean_squared_error(y_test, predictions)
    rmse = sqrt(mse)

    print(f"R2 Score = {r2s}")
    print(f"     MAR = {mae}")
    print(f"     MSE = {mse}")
    print(f"    RMSE = {rmse}")

keys = []
sides = ['Left', 'Right']
attrs = ['x', 'y']

for side in sides:
    for i in range(21):
        for attr in attrs:
            keys.append(f"{side}_{i}_{attr}")


def extract_row(df: pd.DataFrame, index: int) -> pd.DataFrame:
    row = pd.DataFrame(df['data'].iloc[index])

    row_data = pd.DataFrame(columns=keys)

    row_data['timestamp'] = row['timestamp']
    for key in keys:
        row_data[key] = row['data'].apply(lambda x: x.get(key, np.nan))

    row_data.fillna(method='ffill', inplace=True)
    row_data.fillna(method='bfill', inplace=True)
    
    return row_data

def normalize(df: pd.DataFrame, index, WIDTH, HEIGHT) -> pd.DataFrame:
    row = extract_row(df, index)

    corr_prev = tidy_corr_matrix(row.corr())
    before = corr_prev[corr_prev['|Corr|'] > 0.7]['Corr'].count() / corr_prev.shape[0]

    for key in keys:
        if 'x' in key:
            row[key] *= WIDTH
        else:
            row[key] *= HEIGHT

    wrist = dict()
    middle = dict()
    scale = dict()

    for side in sides:
        wrist[side] = dict()
        middle[side] = dict()
        for attr in attrs:
            wrist[side][attr] = row[f"{side}_0_{attr}"].iloc[0]
            middle[side][attr] = row[f"{side}_12_{attr}"].iloc[0]

        scale[side] = sqrt((middle[side]['x'] - wrist[side]['x'])**2 + (middle[side]['y'] - wrist[side]['y'])**2)

    for side in sides:
        for attr in attrs:
            for i in range(1,21):
                key = f"{side}_{i}_{attr}"
                row[key] = (row[key] - row[f"{side}_0_{attr}"]) / scale[side]

        row[f"{side}_0_x"] = row[f"{side}_0_x"] / WIDTH
        row[f"{side}_0_y"] = row[f"{side}_0_y"] / HEIGHT

    corr_after = tidy_corr_matrix(row.corr())
    after = corr_after[corr_after['|Corr|'] > 0.7]['Corr'].count() / corr_after.shape[0]

    print(f"Columns with high correlation >.7 before: {before}")
    print(f"Columns with high correlation >.7 after normalization: {after}")

    return row

# %%
df = pd.read_json('useful.json')
df['target'] = df['filename'].str.split('/').str[1]
df.drop(columns=['filename', 'score'], inplace=True)

print(df.shape)
df.head()
# Out:
# (116, 2)
#                                                   data  target
# 75   [{'timestamp': 0, 'data': {'Left_0_x': 0.66563...  Zapato
# 113  [{'timestamp': 0, 'data': {'Right_0_x': 0.4155...    Niño
# 123  [{'timestamp': 0, 'data': {'Left_0_x': 0.68489...    Niño
# 124  [{'timestamp': 0, 'data': {'Left_0_x': 0.68459...    Niño
# 126  [{'timestamp': 0, 'data': {'Left_0_x': 0.69289...    Niño

# %%
df['target'].value_counts()
# Out:
# target
# Borrar      52
# Encender    27
# Avión       22
# Mal          7
# Niño         5
# Abrir        2
# Zapato       1
# Name: count, dtype: int64

# %%
df['norm'] = [normalize(df, i, 512, 512) for i in range(df.shape[0])]
# Out:
# Columns with high correlation >.7 before: 0.611764705882353
# Columns with high correlation >.7 after normalization: 0.31736694677871147
# Columns with high correlation >.7 before: 0.49411764705882355
# Columns with high correlation >.7 after normalization: 0.3557422969187675
# Columns with high correlation >.7 before: 0.4050420168067227
# Columns with high correlation >.7 after normalization: 0.2064425770308123
# Columns with high correlation >.7 before: 0.43221288515406164
# Columns with high correlation >.7 after normalization: 0.2280112044817927
# Columns with high correlation >.7 before: 0.388515406162465
# Columns with high correlation >.7 after normalization: 0.2571428571428571
# Columns with high correlation >.7 before: 0.3641456582633053
# Columns with high correlation >.7 after normalization: 0.26666666666666666
# Columns with high correlation >.7 before: 0.3619047619047619
# Columns with high correlation >.7 after normalization: 0.3420168067226891
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.31176470588235294
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.230812324929972
# Columns with high correlation >.7 before: 0.2411764705882353
# Columns with high correlation >.7 after normalization: 0.2904761904761905
# Columns with high correlation >.7 before: 0.41008403361344536
# Columns with high correlation >.7 after normalization: 0.27058823529411763
# Columns with high correlation >.7 before: 0.4064425770308123
# Columns with high correlation >.7 after normalization: 0.2991596638655462
# Columns with high correlation >.7 before: 0.36470588235294116
# Columns with high correlation >.7 after normalization: 0.2196078431372549
# Columns with high correlation >.7 before: 0.44985994397759105
# Columns with high correlation >.7 after normalization: 0.2826330532212885
# Columns with high correlation >.7 before: 0.36470588235294116
# Columns with high correlation >.7 after normalization: 0.49523809523809526
# Columns with high correlation >.7 before: 0.4823529411764706
# Columns with high correlation >.7 after normalization: 0.28851540616246496
# Columns with high correlation >.7 before: 0.6182072829131653
# Columns with high correlation >.7 after normalization: 0.25518207282913163
# Columns with high correlation >.7 before: 0.35826330532212886
# Columns with high correlation >.7 after normalization: 0.32212885154061627
# Columns with high correlation >.7 before: 0.5557422969187675
# Columns with high correlation >.7 after normalization: 0.25098039215686274
# Columns with high correlation >.7 before: 0.9224806201550387
# Columns with high correlation >.7 after normalization: 0.39424141749723146
# Columns with high correlation >.7 before: 0.35714285714285715
# Columns with high correlation >.7 after normalization: 0.21792717086834734
# Columns with high correlation >.7 before: 0.9837535014005602
# Columns with high correlation >.7 after normalization: 0.6859943977591036
# Columns with high correlation >.7 before: 0.3596638655462185
# Columns with high correlation >.7 after normalization: 0.269187675070028
# Columns with high correlation >.7 before: 0.3700280112044818
# Columns with high correlation >.7 after normalization: 0.33753501400560226
# Columns with high correlation >.7 before: 0.36834733893557425
# Columns with high correlation >.7 after normalization: 0.25014005602240896
# Columns with high correlation >.7 before: 0.36358543417366945
# Columns with high correlation >.7 after normalization: 0.242296918767507
# Columns with high correlation >.7 before: 0.47507002801120446
# Columns with high correlation >.7 after normalization: 0.30196078431372547
# Columns with high correlation >.7 before: 0.4350140056022409
# Columns with high correlation >.7 after normalization: 0.3941176470588235
# Columns with high correlation >.7 before: 0.3563025210084034
# Columns with high correlation >.7 after normalization: 0.23809523809523808
# Columns with high correlation >.7 before: 0.5084033613445378
# Columns with high correlation >.7 after normalization: 0.25518207282913163
# Columns with high correlation >.7 before: 0.3815126050420168
# Columns with high correlation >.7 after normalization: 0.3226890756302521
# Columns with high correlation >.7 before: 0.42212885154061625
# Columns with high correlation >.7 after normalization: 0.2876750700280112
# Columns with high correlation >.7 before: 0.23837535014005604
# Columns with high correlation >.7 after normalization: 0.2711484593837535
# Columns with high correlation >.7 before: 0.4008403361344538
# Columns with high correlation >.7 after normalization: 0.2815126050420168
# Columns with high correlation >.7 before: 0.5207282913165266
# Columns with high correlation >.7 after normalization: 0.22044817927170868
# Columns with high correlation >.7 before: 0.6753501400560225
# Columns with high correlation >.7 after normalization: 0.1773109243697479
# Columns with high correlation >.7 before: 0.46750700280112045
# Columns with high correlation >.7 after normalization: 0.3277310924369748
# Columns with high correlation >.7 before: 0.39467787114845937
# Columns with high correlation >.7 after normalization: 0.2411764705882353
# Columns with high correlation >.7 before: 0.46106442577030815
# Columns with high correlation >.7 after normalization: 0.2064425770308123
# Columns with high correlation >.7 before: 0.45098039215686275
# Columns with high correlation >.7 after normalization: 0.25434173669467786
# Columns with high correlation >.7 before: 0.4826330532212885
# Columns with high correlation >.7 after normalization: 0.32745098039215687
# Columns with high correlation >.7 before: 0.5638655462184874
# Columns with high correlation >.7 after normalization: 0.4170868347338936
# Columns with high correlation >.7 before: 0.35910364145658263
# Columns with high correlation >.7 after normalization: 0.3787114845938375
# Columns with high correlation >.7 before: 0.584593837535014
# Columns with high correlation >.7 after normalization: 0.3546218487394958
# Columns with high correlation >.7 before: 0.46106442577030815
# Columns with high correlation >.7 after normalization: 0.2061624649859944
# Columns with high correlation >.7 before: 0.8453781512605042
# Columns with high correlation >.7 after normalization: 0.3187675070028011
# Columns with high correlation >.7 before: 0.43669467787114846
# Columns with high correlation >.7 after normalization: 0.23333333333333334
# Columns with high correlation >.7 before: 0.5361344537815126
# Columns with high correlation >.7 after normalization: 0.21876750700280112
# Columns with high correlation >.7 before: 0.37675070028011204
# Columns with high correlation >.7 after normalization: 0.18375350140056024
# Columns with high correlation >.7 before: 0.49327731092436977
# Columns with high correlation >.7 after normalization: 0.2641456582633053
# Columns with high correlation >.7 before: 0.4711484593837535
# Columns with high correlation >.7 after normalization: 0.22661064425770308
# Columns with high correlation >.7 before: 0.4826330532212885
# Columns with high correlation >.7 after normalization: 0.3773109243697479
# Columns with high correlation >.7 before: 0.8910364145658264
# Columns with high correlation >.7 after normalization: 0.5899159663865546
# Columns with high correlation >.7 before: 0.34901960784313724
# Columns with high correlation >.7 after normalization: 0.28627450980392155
# Columns with high correlation >.7 before: 0.6140056022408964
# Columns with high correlation >.7 after normalization: 0.25910364145658266
# Columns with high correlation >.7 before: 0.35042016806722687
# Columns with high correlation >.7 after normalization: 0.22717086834733893
# Columns with high correlation >.7 before: 0.4512605042016807
# Columns with high correlation >.7 after normalization: 0.261624649859944
# Columns with high correlation >.7 before: 0.45182072829131653
# Columns with high correlation >.7 after normalization: 0.5759103641456582
# Columns with high correlation >.7 before: 0.29747899159663865
# Columns with high correlation >.7 after normalization: 0.23109243697478993
# Columns with high correlation >.7 before: 0.3061624649859944
# Columns with high correlation >.7 after normalization: 0.19551820728291316
# Columns with high correlation >.7 before: 0.49411764705882355
# Columns with high correlation >.7 after normalization: 0.40224089635854343
# Columns with high correlation >.7 before: 0.4669467787114846
# Columns with high correlation >.7 after normalization: 0.21428571428571427
# Columns with high correlation >.7 before: 0.8756302521008403
# Columns with high correlation >.7 after normalization: 0.39747899159663863
# Columns with high correlation >.7 before: 0.4823529411764706
# Columns with high correlation >.7 after normalization: 0.19187675070028012
# Columns with high correlation >.7 before: 0.36470588235294116
# Columns with high correlation >.7 after normalization: 0.2761904761904762
# Columns with high correlation >.7 before: 0.3677871148459384
# Columns with high correlation >.7 after normalization: 0.27759103641456584
# Columns with high correlation >.7 before: 0.5305322128851541
# Columns with high correlation >.7 after normalization: 0.2736694677871149
# Columns with high correlation >.7 before: 0.36050420168067226
# Columns with high correlation >.7 after normalization: 0.2815126050420168
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.3072829131652661
# Columns with high correlation >.7 before: 0.25406162464985993
# Columns with high correlation >.7 after normalization: 0.29971988795518206
# Columns with high correlation >.7 before: 0.6058823529411764
# Columns with high correlation >.7 after normalization: 0.3145658263305322
# Columns with high correlation >.7 before: 0.4218487394957983
# Columns with high correlation >.7 after normalization: 0.28095238095238095
# Columns with high correlation >.7 before: 0.2361344537815126
# Columns with high correlation >.7 after normalization: 0.23053221288515408
# Columns with high correlation >.7 before: 0.23529411764705882
# Columns with high correlation >.7 after normalization: 0.18851540616246498
# Columns with high correlation >.7 before: 0.8529411764705882
# Columns with high correlation >.7 after normalization: 0.34145658263305323
# Columns with high correlation >.7 before: 0.39775910364145656
# Columns with high correlation >.7 after normalization: 0.3145658263305322
# Columns with high correlation >.7 before: 0.2593837535014006
# Columns with high correlation >.7 after normalization: 0.21484593837535015
# Columns with high correlation >.7 before: 0.6165266106442577
# Columns with high correlation >.7 after normalization: 0.41680672268907565
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2042016806722689
# Columns with high correlation >.7 before: 0.23529411764705882
# Columns with high correlation >.7 after normalization: 0.2207282913165266
# Columns with high correlation >.7 before: 0.23529411764705882
# Columns with high correlation >.7 after normalization: 0.21400560224089635
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.22745098039215686
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.3366946778711485
# Columns with high correlation >.7 before: 0.35826330532212886
# Columns with high correlation >.7 after normalization: 0.23949579831932774
# Columns with high correlation >.7 before: 0.3630252100840336
# Columns with high correlation >.7 after normalization: 0.24565826330532212
# Columns with high correlation >.7 before: 0.33613445378151263
# Columns with high correlation >.7 after normalization: 0.2064425770308123
# Columns with high correlation >.7 before: 0.215406162464986
# Columns with high correlation >.7 after normalization: 0.19719887955182072
# Columns with high correlation >.7 before: 0.3610644257703081
# Columns with high correlation >.7 after normalization: 0.29943977591036414
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.34145658263305323
# Columns with high correlation >.7 before: 0.36022408963585434
# Columns with high correlation >.7 after normalization: 0.2868347338935574
# Columns with high correlation >.7 before: 0.36022408963585434
# Columns with high correlation >.7 after normalization: 0.2868347338935574
# Columns with high correlation >.7 before: 0.36022408963585434
# Columns with high correlation >.7 after normalization: 0.2868347338935574
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2837535014005602
# Columns with high correlation >.7 before: 0.36022408963585434
# Columns with high correlation >.7 after normalization: 0.29439775910364147
# Columns with high correlation >.7 before: 0.8756302521008403
# Columns with high correlation >.7 after normalization: 0.3700280112044818
# Columns with high correlation >.7 before: 0.36022408963585434
# Columns with high correlation >.7 after normalization: 0.28739495798319326
# Columns with high correlation >.7 before: 0.3641456582633053
# Columns with high correlation >.7 after normalization: 0.24285714285714285
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2859943977591036
# Columns with high correlation >.7 before: 0.36134453781512604
# Columns with high correlation >.7 after normalization: 0.30364145658263303
# Columns with high correlation >.7 before: 0.5400560224089636
# Columns with high correlation >.7 after normalization: 0.25518207282913163
# Columns with high correlation >.7 before: 0.36470588235294116
# Columns with high correlation >.7 after normalization: 0.3366946778711485
# Columns with high correlation >.7 before: 0.36470588235294116
# Columns with high correlation >.7 after normalization: 0.44397759103641454
# Columns with high correlation >.7 before: 0.48515406162464986
# Columns with high correlation >.7 after normalization: 0.26554621848739496
# Columns with high correlation >.7 before: 0.36134453781512604
# Columns with high correlation >.7 after normalization: 0.29831932773109243
# Columns with high correlation >.7 before: 0.6100840336134454
# Columns with high correlation >.7 after normalization: 0.3319327731092437
# Columns with high correlation >.7 before: 0.38823529411764707
# Columns with high correlation >.7 after normalization: 0.2518207282913165
# Columns with high correlation >.7 before: 0.3711484593837535
# Columns with high correlation >.7 after normalization: 0.38375350140056025
# Columns with high correlation >.7 before: 0.36358543417366945
# Columns with high correlation >.7 after normalization: 0.2823529411764706
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2907563025210084
# Columns with high correlation >.7 before: 0.3680672268907563
# Columns with high correlation >.7 after normalization: 0.32605042016806723
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.31708683473389354
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.3100840336134454
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2792717086834734
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.2585434173669468
# Columns with high correlation >.7 before: 0.3588235294117647
# Columns with high correlation >.7 after normalization: 0.28095238095238095
# Columns with high correlation >.7 before: 0.47703081232493
# Columns with high correlation >.7 after normalization: 0.2722689075630252

# %%
df = df[['target', 'norm']]
df.head()
# Out:
#      target                                               norm
# 75   Zapato       Left_0_x  Left_0_y  Left_1_x  Left_1_y  L...
# 113    Niño       Left_0_x  Left_0_y  Left_1_x  Left_1_y  L...
# 123    Niño       Left_0_x  Left_0_y  Left_1_x  Left_1_y  L...
# 124    Niño       Left_0_x  Left_0_y  Left_1_x  Left_1_y  L...
# 126    Niño       Left_0_x  Left_0_y  Left_1_x  Left_1_y  L...

# %%
df['norm'].iloc[0]
# Out:
#      Left_0_x  Left_0_y  Left_1_x  Left_1_y  Left_2_x  Left_2_y  Left_3_x  \
# 0    0.665638  0.853088 -0.222893  0.042188 -0.347041  0.225318 -0.416905
# 1    0.667796  0.852059 -0.227135  0.030394 -0.349200  0.224994 -0.420385
# 2    0.667141  0.851356 -0.229280  0.040806 -0.348483  0.233142 -0.417725
# 3    0.667667  0.851346 -0.230219  0.040259 -0.348810  0.232987 -0.416740
# 4    0.667420  0.851474 -0.228258  0.043191 -0.345513  0.236078 -0.413121
# ..        ...       ...       ...       ...       ...       ...       ...
# 143  0.653788  0.855341 -0.227815  0.021638 -0.366020  0.207181 -0.442780
# 144  0.653998  0.856029 -0.225916  0.021956 -0.363705  0.204376 -0.441380
# 145  0.654706  0.855676 -0.225586  0.020039 -0.364245  0.206424 -0.446537
# 146  0.654105  0.856181 -0.220298  0.027976 -0.353580  0.210758 -0.434509
# 147  0.653636  0.856487 -0.223325  0.019469 -0.359399  0.196149 -0.439876
#
#      Left_3_y  Left_4_x  Left_4_y  ...  Right_16_y  Right_17_x  Right_17_y  \
# 0    0.402914 -0.485756  0.535345  ...    0.845043    0.100688    0.466895
# 1    0.412852 -0.491470  0.556443  ...    0.845043    0.100688    0.466895
# 2    0.417338 -0.487692  0.561047  ...    0.814437    0.128446    0.442308
# 3    0.417714 -0.488075  0.561663  ...    0.810490    0.123870    0.441990
# 4    0.420167 -0.484514  0.561090  ...    0.806894    0.135059    0.436411
# ..        ...       ...       ...  ...         ...         ...         ...
# 143  0.394750 -0.520580  0.541165  ...    0.974026   -0.175893    0.492514
# 144  0.388837 -0.516648  0.534558  ...    0.974026   -0.175893    0.492514
# 145  0.395251 -0.523746  0.543084  ...    0.974026   -0.175893    0.492514
# 146  0.398268 -0.513328  0.544591  ...    0.974026   -0.175893    0.492514
# 147  0.379867 -0.512871  0.526782  ...    0.974026   -0.175893    0.492514
#
#      Right_18_x  Right_18_y  Right_19_x  Right_19_y  Right_20_x  Right_20_y  \
# 0      0.198364    0.620349    0.275103    0.703793    0.336523    0.765314
# 1      0.198364    0.620349    0.275103    0.703793    0.336523    0.765314
# 2      0.222959    0.582519    0.298043    0.657826    0.359503    0.711222
# 3      0.220938    0.587561    0.297804    0.662779    0.361614    0.714817
# 4      0.229593    0.574431    0.305181    0.648928    0.369734    0.700475
# ..          ...         ...         ...         ...         ...         ...
# 143   -0.232614    0.637602   -0.285568    0.725169   -0.338406    0.789663
# 144   -0.232614    0.637602   -0.285568    0.725169   -0.338406    0.789663
# 145   -0.232614    0.637602   -0.285568    0.725169   -0.338406    0.789663
# 146   -0.232614    0.637602   -0.285568    0.725169   -0.338406    0.789663
# 147   -0.232614    0.637602   -0.285568    0.725169   -0.338406    0.789663
#
#      timestamp
# 0            0
# 1           33
# 2           66
# 3          100
# 4          133
# ..         ...
# 143       4833
# 144       4866
# 145       4900
# 146       4933
# 147       4966
#
# [148 rows x 85 columns]

# %%
df.to_json("clean.json")
